# %%
original_dataset_dir = r'photo1500'

# %%
import os
train_dir = os.path.join(original_dataset_dir , 'train')

# %%
for i in train_dir :
    print(i)
# Out:
# p
# h
# o
# t
# o
# 1
# 5
# 0
# 0
# \
# t
# r
# a
# i
# n

# %%
path = '/content/gdrive/MyDrive/NTU/NN/report/photo1500'
train_path = []
for i in range(101):
    pat = path + '/'+str(i) + '.jpg'
    train_path.append(pat)
for i in range(159,1169):
    pat = path + '/'+str(i) + '.jpg'
    train_path.append(pat) 
test_path = []
for i in range(101,121):
    pat = path + '/'+str(i) + '.jpg'
    test_path.append(pat)
for i in range(1169,1369):
    pat = path + '/'+str(i) + '.jpg'
    test_path.append(pat) 

for i in test_path:
    print(i)
# Out:
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/101.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/102.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/103.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/104.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/105.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/106.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/107.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/108.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/109.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/110.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/111.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/112.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/113.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/114.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/115.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/116.jpg
# /content/gdrive/MyDrive/NTU/NN/report/photo1500/117.jpg
# ...

# %%
f = open('test.txt', 'w')
for i in trai_path:
    f.write(i+'\n')
f.close()
